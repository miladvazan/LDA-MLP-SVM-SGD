# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn import discriminant_analysis

# %%
train_df = pd.read_csv("/content/drive/MyDrive/HAR/HAR/Dataset/UCI/train.csv")
test_df = pd.read_csv("/content/drive/MyDrive/HAR/HAR/Dataset/UCI/test.csv")

# %%
train_features = train_df.drop(["Activity", "subject"], axis=1)
test_features = test_df.drop(["Activity", "subject"], axis=1)

train_labels = train_df["Activity"].replace(['LAYING', 'SITTING', 'STANDING', 'WALKING', 'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS'],  [0, 1, 2, 3, 4, 5])
test_labels = test_df["Activity"].replace(['LAYING', 'SITTING', 'STANDING', 'WALKING', 'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS'],  [0, 1, 2, 3, 4, 5])

# %%
stdsc = StandardScaler()
train_features = stdsc.fit_transform(train_features)
test_features = stdsc.fit_transform(test_features)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

class_labels = ['Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5', 'Class 6']

# LDA with 5 components
lda = LinearDiscriminantAnalysis(n_components=5)
lda_fit = lda.fit(train_features, train_labels)
X_train_lda = lda.transform(train_features)

fig = plt.figure(figsize=(15, 6))

# Plotting components 1, 3, and 5
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (train_labels == i)
    ax.scatter(X_train_lda[indices, 0], X_train_lda[indices, 2], X_train_lda[indices, 4], label=class_labels[i])
ax.set_xlabel('LDA Component 1')
ax.set_ylabel('LDA Component 3')
ax.set_zlabel('LDA Component 5')
ax.set_title('LDA Components 1, 3, and 5')
ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (train_labels == i)
    ax.scatter(X_train_lda[indices, 0], X_train_lda[indices, 1], X_train_lda[indices, 2], label=class_labels[i])
ax.set_xlabel('LDA Component 1')
ax.set_ylabel('LDA Component 2')
ax.set_zlabel('LDA Component 3')
ax.set_title('First 3 LDA Components')
ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (train_labels == i)
    ax.scatter(X_train_lda[indices, 1], X_train_lda[indices, 2], X_train_lda[indices, 3], label=class_labels[i])
ax.set_xlabel('LDA Component 2')
ax.set_ylabel('LDA Component 3')
ax.set_zlabel('LDA Component 4')
ax.set_title('LDA Components 2, 3, and 4')
ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (train_labels == i)
    ax.scatter(X_train_lda[indices, 2], X_train_lda[indices, 3], X_train_lda[indices, 4], label=class_labels[i])
ax.set_xlabel('LDA Component 3')
ax.set_ylabel('LDA Component 4')
ax.set_zlabel('LDA Component 5')
ax.set_title('Last 3 LDA Components')
ax.legend()

plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

class_labels = ['Class 1', 'Class 2', 'Class 3', 'Class 4', 'Class 5', 'Class 6']

# LDA with 5 components
lda = LinearDiscriminantAnalysis(n_components=5)
lda_fit = lda.fit(test_features, test_labels)
X_test_lda = lda.transform(test_features)

fig = plt.figure(figsize=(15, 6))

# Plotting components 1, 3, and 5
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (test_labels == i)
    ax.scatter(X_test_lda[indices, 0], X_test_lda[indices, 2], X_test_lda[indices, 4], label=class_labels[i])
ax.set_xlabel('LDA Component 1')
ax.set_ylabel('LDA Component 3')
ax.set_zlabel('LDA Component 5')
ax.set_title('LDA Components 1, 3, and 5')
ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (test_labels == i)
    ax.scatter(X_test_lda[indices, 0], X_test_lda[indices, 1], X_test_lda[indices, 2], label=class_labels[i])
ax.set_xlabel('LDA Component 1')
ax.set_ylabel('LDA Component 2')
ax.set_zlabel('LDA Component 3')
ax.set_title('First 3 LDA Components')
ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (test_labels == i)
    ax.scatter(X_test_lda[indices, 1], X_test_lda[indices, 2], X_test_lda[indices, 3], label=class_labels[i])
ax.set_xlabel('LDA Component 2')
ax.set_ylabel('LDA Component 3')
ax.set_zlabel('LDA Component 4')
ax.set_title('LDA Components 2, 3, and 4')
ax.legend()

plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
ax = fig.add_subplot(111, projection='3d')
for i in range(len(class_labels)):
    indices = (test_labels == i)
    ax.scatter(X_test_lda[indices, 2], X_test_lda[indices, 3], X_test_lda[indices, 4], label=class_labels[i])
ax.set_xlabel('LDA Component 3')
ax.set_ylabel('LDA Component 4')
ax.set_zlabel('LDA Component 5')
ax.set_title('Last 3 LDA Components')
ax.legend()

plt.show()
